# %%
# Any copyright is dedicated to the Public Domain.
# https://creativecommons.org/publicdomain/zero/1.0/

# Adapted from code originally written by Francois Fleuret <francois@fleuret.org>

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import os, time
import numpy as np
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import urllib.request

import requests
import pandas as pd
import io
import datetime
from parse import *
import re
from dateutil.rrule import rrule, DAILY

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Get the JHU timeseries data for confirmed cases, deaths and recoveries

# %%
url1 = 'https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'
url2 = 'https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv'
url3 = 'https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv'

url_dict = {url1:'Confirmed',url2:'Deaths',url3:'Recovered'}

# %%
cf = requests.get(url1).content
df_con = pd.read_csv(io.StringIO(cf.decode('utf-8')))
df_con.name = 'Confirmed'

dd = requests.get(url2).content
df_die = pd.read_csv(io.StringIO(dd.decode('utf-8')))
df_die.name = 'Deaths'

rc = requests.get(url3).content
df_rec = pd.read_csv(io.StringIO(rc.decode('utf-8')))
df_rec.name = 'Recovered'

# %% [markdown]
# ## Table of fractional increase in today's confirmed cases ves. yesterday's

# %% [markdown]
# #### helper function to extract time serise of dates

# %%
def get_dates(df):
    date_cols = df.columns.to_list()
    non_dates = ['Province/State', 'Country/Region', 'Lat', 'Long']
    for item in non_dates:
        date_cols.remove(item)
    return date_cols

# %%
date_cols = get_dates(df_con)
dg_con = df_con.groupby(['Country/Region'])[date_cols].sum(axis=0).sort_values(by=date_cols[-1],ascending=False)
dg_con['%increase'] = 100*(dg_con[date_cols[-1]]-dg_con[date_cols[-2]])/dg_con[date_cols[-1]]
dg_con[[date_cols[-2],date_cols[-1],'%increase']]
# Out:
#                         3/12/20  3/13/20  %increase
# Country/Region
# Afghanistan                   7      0.0       -inf
# Monaco                        2      0.0       -inf
# Paraguay                      5      0.0       -inf
# Panama                       11      0.0       -inf
# Pakistan                     20      0.0       -inf
# Oman                         18      0.0       -inf
# Norway                      702      0.0       -inf
# North Macedonia               7      0.0       -inf
# Nigeria                       2      0.0       -inf
# New Zealand                   5      0.0       -inf
# Netherlands                 503      0.0       -inf
# Nepal                         1      0.0       -inf
# Morocco                       6      0.0       -inf
# Mongolia                      1      0.0       -inf
# Moldova                       3      0.0       -inf
# Albania                      23      0.0       -inf
# Mexico                       12      0.0       -inf
# Martinique                    3      0.0       -inf
# Malta                         6      0.0       -inf
# Maldives                      8      0.0       -inf
# Malaysia                    149      0.0       -inf
# Luxembourg                   19      0.0       -inf
# Lithuania                     3      0.0       -inf
# Liechtenstein                 1      0.0       -inf
# Lebanon                      61      0.0       -inf
# Latvia                       10      0.0       -inf
# Kuwait                       80      0.0       -inf
# Korea, South               7869      0.0       -inf
# Peru                         15      0.0       -inf
# Philippines                  52      0.0       -inf
# Poland                       49      0.0       -inf
# Portugal                     59      0.0       -inf
# United Kingdom              459      0.0       -inf
# United Arab Emirates         85      0.0       -inf
# Ukraine                       1      0.0       -inf
# US                         1663      0.0       -inf
# Turkey                        1      0.0       -inf
# Tunisia                       7      0.0       -inf
# Togo                          1      0.0       -inf
# Thailand                     70      0.0       -inf
# Taiwan*                      49      0.0       -inf
# Switzerland                 652      0.0       -inf
# Sweden                      599      0.0       -inf
# Sri Lanka                     2      0.0       -inf
# Spain                      2277      0.0       -inf
# South Africa                 17      0.0       -inf
# Slovenia                     89      0.0       -inf
# Slovakia                     16      0.0       -inf
# Singapore                   178      0.0       -inf
# Serbia                       19      0.0       -inf
# Senegal                       4      0.0       -inf
# Saudi Arabia                 45      0.0       -inf
# San Marino                   69      0.0       -inf
# Russia                       28      0.0       -inf
# Romania                      49      0.0       -inf
# Reunion                       1      0.0       -inf
# Qatar                       262      0.0       -inf
# Jordan                        1      0.0       -inf
# Japan                       639      0.0       -inf
# Jamaica                       2      0.0       -inf
# Cote d'Ivoire                 1      0.0       -inf
# Congo (Kinshasa)              1      0.0       -inf
# Colombia                      9      0.0       -inf
# China                     80932      0.0       -inf
# Chile                        23      0.0       -inf
# Canada                      117      0.0       -inf
# Cameroon                      2      0.0       -inf
# Cambodia                      3      0.0       -inf
# Burkina Faso                  2      0.0       -inf
# Bulgaria                      7      0.0       -inf
# Brunei                       11      0.0       -inf
# Brazil                       52      0.0       -inf
# Bosnia and Herzegovina       11      0.0       -inf
# Bolivia                       2      0.0       -inf
# Bhutan                        1      0.0       -inf
# Belgium                     314      0.0       -inf
# Belarus                      12      0.0       -inf
# Bangladesh                    3      0.0       -inf
# Bahrain                     195      0.0       -inf
# Azerbaijan                   11      0.0       -inf
# Austria                     302      0.0       -inf
# Australia                   128      0.0       -inf
# Armenia                       4      0.0       -inf
# Argentina                    19      0.0       -inf
# Andorra                       1      0.0       -inf
# Algeria                      24      0.0       -inf
# Costa Rica                   22      0.0       -inf
# Croatia                      19      0.0       -inf
# Italy                     12462      0.0       -inf
# Cruise Ship                 696      0.0       -inf
# Israel                      131      0.0       -inf
# Ireland                      43      0.0       -inf
# Iraq                         71      0.0       -inf
# Iran                      10075      0.0       -inf
# Indonesia                    34      0.0       -inf
# India                        73      0.0       -inf
# Iceland                     103      0.0       -inf
# Hungary                      13      0.0       -inf
# Honduras                      2      0.0       -inf
# Holy See                      1      0.0       -inf
# Guyana                        1      0.0       -inf
# Greece                       99      0.0       -inf
# Germany                    2078      0.0       -inf
# Georgia                      24      0.0       -inf
# French Guiana                 5      0.0       -inf
# France                     2284      0.0       -inf
# Finland                      59      0.0       -inf
# Estonia                      16      0.0       -inf
# Egypt                        67      0.0       -inf
# Ecuador                      17      0.0       -inf
# Dominican Republic            5      0.0       -inf
# Denmark                     617      0.0       -inf
# Czechia                      94      0.0       -inf
# Cyprus                        6      0.0       -inf
# Cuba                          3      0.0       -inf
# Vietnam                      39      0.0       -inf

# %% [markdown]
# ## Time series plot helper function

# %%
def plot_timeseries(df):
    
    #df.sort_values(by=df.columns[-1],ascending=False, inplace = True)
    
    
    date_cols = df.columns.to_list()
    non_dates = ['Province/State', 'Country/Region', 'Lat', 'Long']
    for item in non_dates:
        date_cols.remove(item)

    dg = df.groupby(['Country/Region'])[date_cols].sum(axis=0).sort_values(by=date_cols[-1],ascending=False)
    
    times = [datetime.datetime.strptime(col,'%m/%d/%y') for col in dg.columns]

    fig = plt.figure(figsize=(10,6))
    ax = fig.add_subplot(1, 1, 1)
    ax.xaxis_date()

    ax.yaxis.grid(color='gray', linestyle='-', linewidth=0.25)
    ax.set_title('Cumulative number of COVID-19 cases: ' + df.name)
    ax.set_xlabel('Date', labelpad = 10)
    ax.set_ylabel('Counts', labelpad = 10)
    ax.set_yscale('log')

    myFmt = mdates.DateFormatter('%b %d')

    ax.xaxis.set_major_formatter(myFmt)
    #dates = mdates.epoch2num(times)

    #dates = mdates.date2num(times)
    dates=times
    #dates = list(rrule(freq=DAILY, dtstart=times[0]))
    
    
    for key, color, label in [
            ('Germany', 'blue', 'Germany'),
            ('Spain', 'red', 'Spain'),
            ('France', 'lightgreen', 'France'),
            ('US', 'black', 'USA'),
            ('Korea, South', 'gray', 'South Korea'),
            ('Italy', 'purple', 'Italy'),
            ('China', 'orange', 'China'),
            ('Iran', 'cyan', 'Iran')
    ]:
        ax.plot(dates, dg.loc()[key], color = color, label = label, linewidth=2)

    ax.legend(frameon = True)
    plt.xticks(rotation=75)
    plt.show()
    

    
    png_name = 'COVID-19-'+df.name+'.png'

    #fig.savefig('covid19_confirmed.png')
    fig.savefig(png_name)

# %% [markdown]
# ## Plot  `Confirmed`, `Deaths`, and `Recoveries`  timeseries

# %%
for df in [df_con, df_die, df_rec]:
    print(df.name)
    plot_timeseries(df)
# Out:
# Confirmed
# Deaths
# Recovered
